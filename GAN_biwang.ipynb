# %%
import tensorflow as tf

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.test.gpu_device_name())
# Out:
# Num GPUs Available:  4
# /device:GPU:0
# 2022-07-16 19:03:35.459197: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-16 19:03:37.079640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:0 with 38419 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# 2022-07-16 19:03:37.081572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:1 with 38419 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# 2022-07-16 19:03:37.082202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:2 with 38419 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2022-07-16 19:03:37.082807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:3 with 38419 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0

# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
import pandas as pd
import xarray as xr
import h5py

import matplotlib.pyplot as plt

from datetime import datetime
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.layers import Input, Lambda, LeakyReLU, Add, Dense, Activation, Flatten, Conv2D, Conv2DTranspose, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform, constant, TruncatedNormal

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("./lib")
from preprocess import *
from models import *
from GAN_class import *

# %%
output_folder = "../data/preprocessed/"
file_format = "np_gan_standard"
xy_keyword_dict = {"x":"low", "y":"high"}
data_xy = get_data_xy_from_h5(output_folder, file_format, xy_keyword_dict, exclude_list = ["stddev", "mean"])
# Out:
# Data in file ../data/preprocessed/np_gan_standard.h5 are:
#  ['np_perdigao_high_res_1H_2020_mean', 'np_perdigao_high_res_1H_2020_std', 'np_perdigao_high_res_1H_2020_stddev', 'np_perdigao_low_res_1H_2020_mean', 'np_perdigao_low_res_1H_2020_std', 'np_perdigao_low_res_1H_2020_stddev']
# Examining data np_perdigao_high_res_1H_2020_mean
# Examining data np_perdigao_high_res_1H_2020_std
# Examining data np_perdigao_high_res_1H_2020_stddev
# Examining data np_perdigao_low_res_1H_2020_mean
# Examining data np_perdigao_low_res_1H_2020_std
# Loading data np_perdigao_low_res_1H_2020_std from file ../data/preprocessed/np_gan_standard.h5
# Data in file ../data/preprocessed/np_gan_standard.h5 are:
#  ['np_perdigao_high_res_1H_2020_mean', 'np_perdigao_high_res_1H_2020_std', 'np_perdigao_high_res_1H_2020_stddev', 'np_perdigao_low_res_1H_2020_mean', 'np_perdigao_low_res_1H_2020_std', 'np_perdigao_low_res_1H_2020_stddev']
# Examining data np_perdigao_high_res_1H_2020_mean
# Examining data np_perdigao_high_res_1H_2020_std
# Loading data np_perdigao_high_res_1H_2020_std from file ../data/preprocessed/np_gan_standard.h5
# Got data_x with shape:(8520, 96, 96, 2), data_y with shape:(8520, 192, 192, 2)

# %%
SR_GAN = AWWSM4_SR_GAN(data_xy["data_x"], data_xy["data_y"])
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 96, 96, 2)]  0           []
#
#  conv2d_transpose_102 (Conv2DTr  (None, 96, 96, 64)  1216        ['input_5[0][0]']
#  anspose)
#
#  activation_36 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_102[0][0]']
#
#  conv2d_transpose_103 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_36[0][0]']
#  anspose)
#
#  activation_37 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_103[0][0]']
#
#  conv2d_transpose_104 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_37[0][0]']
#  anspose)
#
#  add_64 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_104[0][0]',
#                                                                   'activation_36[0][0]']
#
#  conv2d_transpose_105 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_64[0][0]']
#  anspose)
#
#  activation_38 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_105[0][0]']
#
#  conv2d_transpose_106 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_38[0][0]']
#  anspose)
#
#  add_65 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_106[0][0]',
#                                                                   'add_64[0][0]']
#
#  conv2d_transpose_107 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_65[0][0]']
#  anspose)
#
#  activation_39 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_107[0][0]']
#
#  conv2d_transpose_108 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_39[0][0]']
#  anspose)
#
#  add_66 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_108[0][0]',
#                                                                   'add_65[0][0]']
#
#  conv2d_transpose_109 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_66[0][0]']
#  anspose)
#
#  activation_40 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_109[0][0]']
#
#  conv2d_transpose_110 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_40[0][0]']
#  anspose)
#
#  add_67 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_110[0][0]',
#                                                                   'add_66[0][0]']
#
#  conv2d_transpose_111 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_67[0][0]']
#  anspose)
#
#  activation_41 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_111[0][0]']
#
#  conv2d_transpose_112 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_41[0][0]']
#  anspose)
#
#  add_68 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_112[0][0]',
#                                                                   'add_67[0][0]']
#
#  conv2d_transpose_113 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_68[0][0]']
#  anspose)
#
#  activation_42 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_113[0][0]']
#
#  conv2d_transpose_114 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_42[0][0]']
#  anspose)
#
#  add_69 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_114[0][0]',
#                                                                   'add_68[0][0]']
#
#  conv2d_transpose_115 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_69[0][0]']
#  anspose)
#
#  activation_43 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_115[0][0]']
#
#  conv2d_transpose_116 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_43[0][0]']
#  anspose)
#
#  add_70 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_116[0][0]',
#                                                                   'add_69[0][0]']
#
#  conv2d_transpose_117 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_70[0][0]']
#  anspose)
#
#  activation_44 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_117[0][0]']
#
#  conv2d_transpose_118 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_44[0][0]']
#  anspose)
#
#  add_71 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_118[0][0]',
#                                                                   'add_70[0][0]']
#
#  conv2d_transpose_119 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_71[0][0]']
#  anspose)
#
#  activation_45 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_119[0][0]']
#
#  conv2d_transpose_120 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_45[0][0]']
#  anspose)
#
#  add_72 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_120[0][0]',
#                                                                   'add_71[0][0]']
#
#  conv2d_transpose_121 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_72[0][0]']
#  anspose)
#
#  activation_46 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_121[0][0]']
#
#  conv2d_transpose_122 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_46[0][0]']
#  anspose)
#
#  add_73 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_122[0][0]',
#                                                                   'add_72[0][0]']
#
#  conv2d_transpose_123 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_73[0][0]']
#  anspose)
#
#  activation_47 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_123[0][0]']
#
#  conv2d_transpose_124 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_47[0][0]']
#  anspose)
#
#  add_74 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_124[0][0]',
#                                                                   'add_73[0][0]']
#
#  conv2d_transpose_125 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_74[0][0]']
#  anspose)
#
#  activation_48 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_125[0][0]']
#
#  conv2d_transpose_126 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_48[0][0]']
#  anspose)
#
#  add_75 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_126[0][0]',
#                                                                   'add_74[0][0]']
#
#  conv2d_transpose_127 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_75[0][0]']
#  anspose)
#
#  activation_49 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_127[0][0]']
#
#  conv2d_transpose_128 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_49[0][0]']
#  anspose)
#
#  add_76 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_128[0][0]',
#                                                                   'add_75[0][0]']
#
#  conv2d_transpose_129 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_76[0][0]']
#  anspose)
#
#  activation_50 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_129[0][0]']
#
#  conv2d_transpose_130 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_50[0][0]']
#  anspose)
#
#  add_77 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_130[0][0]',
#                                                                   'add_76[0][0]']
#
#  conv2d_transpose_131 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_77[0][0]']
#  anspose)
#
#  activation_51 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_131[0][0]']
#
#  conv2d_transpose_132 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_51[0][0]']
#  anspose)
#
#  add_78 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_132[0][0]',
#                                                                   'add_77[0][0]']
#
#  conv2d_transpose_133 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_78[0][0]']
#  anspose)
#
#  activation_52 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_133[0][0]']
#
#  conv2d_transpose_134 (Conv2DTr  (None, 96, 96, 64)  36928       ['activation_52[0][0]']
#  anspose)
#
#  add_79 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_134[0][0]',
#                                                                   'add_78[0][0]']
#
#  conv2d_transpose_135 (Conv2DTr  (None, 96, 96, 64)  36928       ['add_79[0][0]']
#  anspose)
#
#  add_80 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_135[0][0]',
#                                                                   'activation_36[0][0]']
#
#  conv2d_transpose_136 (Conv2DTr  (None, 96, 96, 256)  147712     ['add_80[0][0]']
#  anspose)
#
#  lambda_2 (Lambda)              (None, 192, 192, 64  0           ['conv2d_transpose_136[0][0]']
#                                 )
#
#  activation_53 (Activation)     (None, 192, 192, 64  0           ['lambda_2[0][0]']
#                                 )
#
#  conv2d_transpose_137 (Conv2DTr  (None, 192, 192, 2)  1154       ['activation_53[0][0]']
#  anspose)
#
# ==================================================================================================
# Total params: 1,368,706
# Trainable params: 1,368,706
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 192, 192, 2)]     0
#
#  conv2d_16 (Conv2D)          (None, 192, 192, 32)      608
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 192, 192, 32)      0
#
#  conv2d_17 (Conv2D)          (None, 96, 96, 32)        9248
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 96, 96, 32)        0
#
#  conv2d_18 (Conv2D)          (None, 96, 96, 64)        18496
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 96, 96, 64)        0
#
#  conv2d_19 (Conv2D)          (None, 48, 48, 64)        36928
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 48, 48, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 48, 48, 128)       73856
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 48, 48, 128)       0
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 128)       147584
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 24, 24, 128)       0
#
#  conv2d_22 (Conv2D)          (None, 24, 24, 256)       295168
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 24, 24, 256)       0
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 256)       590080
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 12, 12, 256)       0
#
#  flatten_2 (Flatten)         (None, 36864)             0
#
#  dense_4 (Dense)             (None, 1024)              37749760
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 1024)              0
#
#  dense_5 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 38,922,753
# Trainable params: 38,922,753
# Non-trainable params: 0
# _________________________________________________________________
# None
