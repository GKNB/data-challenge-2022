# %%
import tensorflow as tf

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.test.gpu_device_name())
# Out:
# Num GPUs Available:  4
# /device:GPU:0
# 2022-07-17 08:44:12.855096: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-17 08:44:14.259022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:0 with 38417 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# 2022-07-17 08:44:14.260224: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:1 with 38417 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# 2022-07-17 08:44:14.260860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:2 with 38417 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2022-07-17 08:44:14.261497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:3 with 38417 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0

# %%
import numpy as np
import pandas as pd
import xarray as xr
import h5py

import matplotlib.pyplot as plt

from datetime import datetime
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.layers import Input, Lambda, LeakyReLU, Add, Dense, Activation, Flatten, Conv2D, Conv2DTranspose, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform, constant, TruncatedNormal

# %matplotlib inline

# %%
with h5py.File('../processed_data/np_gan_standard.h5', 'r') as hf:
    data_lr = hf['np_lr'][:]
    data_lr_mean = hf['np_lr_mean'][:]
    data_lr_stddev = hf['np_lr_stddev'][:]
    data_hr = hf['np_hr'][:]
    data_hr_mean = hf['np_hr_mean'][:]
    data_hr_stddev = hf['np_hr_stddev'][:]

# %%
print(data_lr.shape)
print(data_lr_mean)
print(data_lr_stddev)
print('\n')
print(data_hr.shape)
print(data_hr_mean)
print(data_hr_stddev)
# Out:
# (8520, 96, 96, 2)
# [ 0.7051484 -1.0147774]
# [3.1869051 2.8827915]
#
#
# (8520, 192, 192, 2)
# [ 0.701198  -1.0068085]
# [3.149407  2.8781955]

# %%
#First split data into train+validation and test set
x_train, x_test, y_train, y_test = train_test_split(data_lr, data_hr, test_size=0.2, random_state=42)

#Next split training again into train and validation
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)

print(y_train.shape)
print(y_val.shape)
print(y_test.shape)

print(np.max(x_train), np.max(x_val), np.max(x_test), np.min(x_train), np.min(x_val), np.min(x_test))
print(np.max(y_train), np.max(y_val), np.max(y_test), np.min(y_train), np.min(y_val), np.min(y_test))
# Out:
# (5112, 96, 96, 2)
# (1704, 96, 96, 2)
# (1704, 96, 96, 2)
# (5112, 192, 192, 2)
# (1704, 192, 192, 2)
# (1704, 192, 192, 2)
# 6.890482 5.989441 5.7024393 -5.4777956 -5.0524907 -5.5057893
# 7.035497 5.8600492 6.0442076 -5.315754 -5.2317853 -5.2996855

# %%
def generator(input_shape = (96, 96, 2), nf = 64, r = 2):
    """
    Arguments:
    input_shape -- shape of the images of the dataset, H*W*C
    nf -- integer, the number of filters in all convT layer before super-resolution step
    r -- integer, resolution ratio between output and input

    Returns:
    model -- a Model() instance in Keras
    """
    
    C0 = input_shape[2]
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Define kernel size and stride used
    k, stride = 3, 1
    
    # Shall we use a mirror padding and finally cutoff the edge, like the paper does? FIXME
    X = Conv2DTranspose(filters=nf, kernel_size=(k, k), strides=(stride, stride), padding='same')(X_input)
    # Shall we use relu, or leaky_relu? FIXME
    X = Activation('relu')(X)

    skip_connection = X
    
    for i in range(16):
        X_shortcut = X
        
        X = Conv2DTranspose(filters=nf, kernel_size=(k, k), strides=(stride, stride), padding='same')(X)
        X = Activation('relu')(X)
        X = Conv2DTranspose(filters=nf, kernel_size=(k, k), strides=(stride, stride), padding='same')(X)
        X = Add()([X, X_shortcut])
        # Are we missing a relu activation here, if we follow the resnet paper? FIXME
    
    X = Conv2DTranspose(filters=nf, kernel_size=(k, k), strides=(stride, stride), padding='same')(X)
    X = Add()([X, skip_connection])
    
    # Start to perform sr
    nf_sr = (r**2) * nf
    X = Conv2DTranspose(filters=nf_sr, kernel_size=(k, k), strides=(stride, stride), padding='same')(X)
    
    sub_layer = Lambda(lambda x:tf.nn.depth_to_space(x,r))
    X = sub_layer(X)
    X = Activation('relu')(X)
    
    X = Conv2DTranspose(filters=C0, kernel_size=(k, k), strides=(stride, stride), padding='same')(X)
    
    model = Model(inputs = X_input, outputs = X)
    
    return model

# %%
gen_model = generator(input_shape = (96, 96, 2))
print(gen_model.summary())
# Out:
# 2022-07-17 08:44:26.224909: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38417 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# 2022-07-17 08:44:26.225286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38417 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# 2022-07-17 08:44:26.225652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38417 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2022-07-17 08:44:26.226034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 38417 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 2)]  0           []
#
#  conv2d_transpose (Conv2DTransp  (None, 96, 96, 64)  1216        ['input_1[0][0]']
#  ose)
#
#  activation (Activation)        (None, 96, 96, 64)   0           ['conv2d_transpose[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 96, 96, 64)  36928       ['activation[0][0]']
#  spose)
#
#  activation_1 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 96, 96, 64)  36928       ['activation_1[0][0]']
#  spose)
#
#  add (Add)                      (None, 96, 96, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 96, 96, 64)  36928       ['add[0][0]']
#  spose)
#
#  activation_2 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_3[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 96, 96, 64)  36928       ['activation_2[0][0]']
#  spose)
#
#  add_1 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_4[0][0]',
#                                                                   'add[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 96, 96, 64)  36928       ['add_1[0][0]']
#  spose)
#
#  activation_3 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_5[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 96, 96, 64)  36928       ['activation_3[0][0]']
#  spose)
#
#  add_2 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_6[0][0]',
#                                                                   'add_1[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 96, 96, 64)  36928       ['add_2[0][0]']
#  spose)
#
#  activation_4 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_7[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 96, 96, 64)  36928       ['activation_4[0][0]']
#  spose)
#
#  add_3 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_8[0][0]',
#                                                                   'add_2[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 96, 96, 64)  36928       ['add_3[0][0]']
#  spose)
#
#  activation_5 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_9[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_5[0][0]']
#  nspose)
#
#  add_4 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_10[0][0]',
#                                                                   'add_3[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_4[0][0]']
#  nspose)
#
#  activation_6 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_11[0][0]']
#
#  conv2d_transpose_12 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_6[0][0]']
#  nspose)
#
#  add_5 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_12[0][0]',
#                                                                   'add_4[0][0]']
#
#  conv2d_transpose_13 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_5[0][0]']
#  nspose)
#
#  activation_7 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_13[0][0]']
#
#  conv2d_transpose_14 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_7[0][0]']
#  nspose)
#
#  add_6 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_14[0][0]',
#                                                                   'add_5[0][0]']
#
#  conv2d_transpose_15 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_6[0][0]']
#  nspose)
#
#  activation_8 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_15[0][0]']
#
#  conv2d_transpose_16 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_8[0][0]']
#  nspose)
#
#  add_7 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_16[0][0]',
#                                                                   'add_6[0][0]']
#
#  conv2d_transpose_17 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_7[0][0]']
#  nspose)
#
#  activation_9 (Activation)      (None, 96, 96, 64)   0           ['conv2d_transpose_17[0][0]']
#
#  conv2d_transpose_18 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_9[0][0]']
#  nspose)
#
#  add_8 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_18[0][0]',
#                                                                   'add_7[0][0]']
#
#  conv2d_transpose_19 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_8[0][0]']
#  nspose)
#
#  activation_10 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_19[0][0]']
#
#  conv2d_transpose_20 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_10[0][0]']
#  nspose)
#
#  add_9 (Add)                    (None, 96, 96, 64)   0           ['conv2d_transpose_20[0][0]',
#                                                                   'add_8[0][0]']
#
#  conv2d_transpose_21 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_9[0][0]']
#  nspose)
#
#  activation_11 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_21[0][0]']
#
#  conv2d_transpose_22 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_11[0][0]']
#  nspose)
#
#  add_10 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_22[0][0]',
#                                                                   'add_9[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_10[0][0]']
#  nspose)
#
#  activation_12 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_23[0][0]']
#
#  conv2d_transpose_24 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_12[0][0]']
#  nspose)
#
#  add_11 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_24[0][0]',
#                                                                   'add_10[0][0]']
#
#  conv2d_transpose_25 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_11[0][0]']
#  nspose)
#
#  activation_13 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_25[0][0]']
#
#  conv2d_transpose_26 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_13[0][0]']
#  nspose)
#
#  add_12 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_26[0][0]',
#                                                                   'add_11[0][0]']
#
#  conv2d_transpose_27 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_12[0][0]']
#  nspose)
#
#  activation_14 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_27[0][0]']
#
#  conv2d_transpose_28 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_14[0][0]']
#  nspose)
#
#  add_13 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_28[0][0]',
#                                                                   'add_12[0][0]']
#
#  conv2d_transpose_29 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_13[0][0]']
#  nspose)
#
#  activation_15 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_29[0][0]']
#
#  conv2d_transpose_30 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_15[0][0]']
#  nspose)
#
#  add_14 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_30[0][0]',
#                                                                   'add_13[0][0]']
#
#  conv2d_transpose_31 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_14[0][0]']
#  nspose)
#
#  activation_16 (Activation)     (None, 96, 96, 64)   0           ['conv2d_transpose_31[0][0]']
#
#  conv2d_transpose_32 (Conv2DTra  (None, 96, 96, 64)  36928       ['activation_16[0][0]']
#  nspose)
#
#  add_15 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_32[0][0]',
#                                                                   'add_14[0][0]']
#
#  conv2d_transpose_33 (Conv2DTra  (None, 96, 96, 64)  36928       ['add_15[0][0]']
#  nspose)
#
#  add_16 (Add)                   (None, 96, 96, 64)   0           ['conv2d_transpose_33[0][0]',
#                                                                   'activation[0][0]']
#
#  conv2d_transpose_34 (Conv2DTra  (None, 96, 96, 256)  147712     ['add_16[0][0]']
#  nspose)
#
#  lambda (Lambda)                (None, 192, 192, 64  0           ['conv2d_transpose_34[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 192, 192, 64  0           ['lambda[0][0]']
#                                 )
#
#  conv2d_transpose_35 (Conv2DTra  (None, 192, 192, 2)  1154       ['activation_17[0][0]']
#  nspose)
#
# ==================================================================================================
# Total params: 1,368,706
# Trainable params: 1,368,706
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
def discriminator(input_shape = (192, 192, 2)):
    """
    Arguments:
    input_shape -- shape of the images of the dataset, H*W*C

    Returns:
    model -- a Model() instance in Keras
    """
    
    C0 = input_shape[2]
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)
    
    #conv1
    X = Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding="same")(X_input)
    X = LeakyReLU(alpha=0.2)(X)
    
    #conv2
    X = Conv2D(filters=32, kernel_size=(3,3), strides=(2,2), padding="same")(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    #conv3
    X = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding="same")(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    #conv4
    X = Conv2D(filters=64, kernel_size=(3,3), strides=(2,2), padding="same")(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    #conv5
    X = Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding="same")(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    #conv6
    X = Conv2D(filters=128, kernel_size=(3,3), strides=(2,2), padding="same")(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    #conv7
    X = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding="same")(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    #conv8
    X = Conv2D(filters=256, kernel_size=(3,3), strides=(2,2), padding="same")(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    X = Flatten()(X)
    
    #first fully-connect
    k_init = TruncatedNormal(stddev=0.02)
    X = Dense(units=1024, kernel_initializer=k_init)(X)
    X = LeakyReLU(alpha=0.2)(X)
    
    #second fully-connect, no activation FIXME
    X = Dense(units=1, kernel_initializer=k_init)(X)
    
    model = Model(inputs = X_input, outputs = X)
    return model

# %%
disc_model = discriminator(input_shape = (192, 192, 2))
print(disc_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 192, 192, 2)]     0
#
#  conv2d (Conv2D)             (None, 192, 192, 32)      608
#
#  leaky_re_lu (LeakyReLU)     (None, 192, 192, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 32)        9248
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 96, 96, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 64)        18496
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 96, 96, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 64)        36928
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 48, 48, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 128)       73856
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 48, 48, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 24, 24, 128)       147584
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 24, 24, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 256)       295168
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 24, 24, 256)       0
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 256)       590080
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 12, 12, 256)       0
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 1024)              37749760
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 38,922,753
# Trainable params: 38,922,753
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def generator_only_loss(x_HR, x_SR):
    content_loss = tf.reduce_mean((x_HR - x_SR)**2)   
    return content_loss

def generator_loss(x_HR, x_SR, d_SR, alpha_advers=0.001):
    
    content_loss = tf.reduce_mean((x_HR - x_SR)**2)
    g_advers_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_SR, labels=tf.ones_like(d_SR)))
    g_loss = content_loss + alpha_advers * g_advers_loss
    
    return g_loss, content_loss, g_advers_loss

#def discriminator_loss(d_HR, d_SR):
#   
#    return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=tf.concat([d_HR, d_SR], axis=0),
#                                                                  labels=tf.concat([tf.ones_like(d_HR), tf.zeros_like(d_SR)], axis=0)))

def discriminator_loss(d_HR, d_SR):
    
    advers_perf = [tf.reduce_mean(tf.cast(tf.sigmoid(d_HR) > 0.5, tf.float32)), # % true positive
                       tf.reduce_mean(tf.cast(tf.sigmoid(d_SR) < 0.5, tf.float32)), # % true negative
                       tf.reduce_mean(tf.cast(tf.sigmoid(d_SR) > 0.5, tf.float32)), # % false positive
                       tf.reduce_mean(tf.cast(tf.sigmoid(d_HR) < 0.5, tf.float32))] # % false negative
    
    return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=tf.concat([d_HR, d_SR], axis=0),
                                                                  labels=tf.concat([tf.ones_like(d_HR), tf.zeros_like(d_SR)], axis=0))), advers_perf

# %%
gen_model.load_weights("generator_pretrain/saved-model-0720.hdf5")

# %%
print(generator_only_loss(y_test, gen_model.predict(x_test)))
# Out:
# 2022-07-17 08:44:36.185950: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8302
# 54/54 [==============================] - 7s 31ms/step
# tf.Tensor(0.011877065, shape=(), dtype=float32)

# %%
from time import time

@tf.function
def train_step(generator, discriminator, generator_optimizer, discriminator_optimizer, batch_LR, batch_HR, alpha_advers=0.001):
    
    g_count = 0
    d_loss = tf.constant(0.0)
    d_HR = discriminator(batch_HR, training=False)
    while(d_loss < tf.constant(0.45) and g_count < 40):
        g_count += 1
        with tf.GradientTape() as gen_tape:
            batch_SR = generator(batch_LR, training=True)
            d_SR = discriminator(batch_SR, training=False)
            g_loss, content_loss, g_advers_loss = generator_loss(batch_HR, batch_SR, d_SR, alpha_advers=alpha_advers)

        grad_of_gen = gen_tape.gradient(g_loss, generator.trainable_variables)
        generator_optimizer.apply_gradients(zip(grad_of_gen, generator.trainable_variables))
        d_loss, _ = discriminator_loss(d_HR, d_SR)

    d_count = 0
    d_loss = tf.constant(100.0)
    while(d_loss > tf.constant(0.65) and d_count < 40):
        d_count += 1
        with tf.GradientTape() as disc_tape:
            batch_SR = generator(batch_LR, training=False)
            d_HR = discriminator(batch_HR, training=True)
            d_SR = discriminator(batch_SR, training=True)
            d_loss, _ = discriminator_loss(d_HR, d_SR)

        grad_of_disc = disc_tape.gradient(d_loss, discriminator.trainable_variables)
        discriminator_optimizer.apply_gradients(zip(grad_of_disc, discriminator.trainable_variables))
       
    return g_loss, d_loss, g_count, d_count

def train(gen_model, disc_model, epochs=20, batch_size=128, alpha_advers=0.001):
    '''
        This method trains the generator and disctiminator adversarially
        Notice the two model should be argument of this function
        output: generator model and discriminator model
    '''

    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size)
    batch_count = tf.data.experimental.cardinality(train_dataset)
    
    g_opt = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    d_opt = tf.keras.optimizers.Adam(learning_rate=4e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

    # Start training
    print('Training network ...')
    for epoch in range(1, epochs+1):
        print('Epoch: %d' %(epoch))
        start_time = time()
        epoch_g_loss, epoch_d_loss, N, g_count_tot, d_count_tot = 0, 0, 0, 0, 0
        
        for batch_idx, (batch_LR, batch_HR) in enumerate(train_dataset):
            N_batch = batch_LR.shape[0]
            g_loss, d_loss, g_count, d_count = train_step(gen_model, disc_model, g_opt, d_opt, batch_LR, batch_HR, alpha_advers)
            
            epoch_g_loss += g_loss * N_batch
            epoch_d_loss += d_loss * N_batch
            N += N_batch
            g_count_tot += g_count
            d_count_tot += d_count

        epoch_g_loss = epoch_g_loss / N       
        epoch_d_loss = epoch_d_loss / N       
        
        val_SR = gen_model.predict(x_val, verbose=0)
        val_d_HR = disc_model.predict(y_val, verbose=0)
        val_d_SR = disc_model.predict(val_SR, verbose=0)
        
        val_g_loss, val_content_loss, val_advers_loss = generator_loss(y_val, val_SR, val_d_SR, alpha_advers)
        val_d_loss, val_disc_perf = discriminator_loss(val_d_HR, val_d_SR)
        
        print('Epoch generator loss = %.6f, discriminator loss = %.6f, g_count = %d, d_count = %d' %(epoch_g_loss, epoch_d_loss, g_count_tot, d_count_tot))
        print('Epoch val: g_loss = %.6f, d_loss = %.6f, content_loss = %.6f, advers_loss = %.6f' \
              %(val_g_loss, val_d_loss, val_content_loss, val_advers_loss))
        print('Epoch val disc perf: TP=%.5f, TN=%.5f, FP=%.5f, FN=%.5f' %(val_disc_perf[0], val_disc_perf[1], val_disc_perf[2], val_disc_perf[3]))
        print('Epoch took %.2f seconds\n' %(time() - start_time), flush=True)
        
        if (epoch % 10 == 0):
            gen_model.save('gan_train/gen-model-epoch-%d.h5' %(epoch))
            disc_model.save('gan_train/disc-model-epoch-%d.h5' %(epoch))

    print('Done.')

    return gen_model, disc_model

# %%
gen_model_final, disc_model_final = train(gen_model, disc_model, epochs=100, batch_size=128, alpha_advers=0.001)
# Out:
# Training network ...
# Epoch: 1
# Epoch generator loss = 0.014066, discriminator loss = 0.633818, g_count = 40, d_count = 50
# Epoch val: g_loss = 0.013259, d_loss = 0.643441, content_loss = 0.012493, advers_loss = 0.765912
# Epoch val disc perf: TP=0.63850, TN=0.73357, FP=0.26643, FN=0.36150
# Epoch took 37.96 seconds
#
# Epoch: 2
# Epoch generator loss = 0.011368, discriminator loss = 0.637378, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.012871, d_loss = 0.627145, content_loss = 0.012039, advers_loss = 0.831699
# Epoch val disc perf: TP=0.58392, TN=0.86854, FP=0.13146, FN=0.41608
# Epoch took 27.92 seconds
#
# Epoch: 3
# Epoch generator loss = 0.011144, discriminator loss = 0.617676, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.012879, d_loss = 0.596519, content_loss = 0.012044, advers_loss = 0.834565
# Epoch val disc perf: TP=0.74413, TN=0.79519, FP=0.20481, FN=0.25587
# Epoch took 27.98 seconds
#
# Epoch: 4
# Epoch generator loss = 0.011159, discriminator loss = 0.593160, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.012715, d_loss = 0.597425, content_loss = 0.012056, advers_loss = 0.659042
# Epoch val disc perf: TP=0.95716, TN=0.42019, FP=0.57981, FN=0.04284
# Epoch took 27.96 seconds
#
# Epoch: 5
# Epoch generator loss = 0.011205, discriminator loss = 0.571660, g_count = 40, d_count = 43
# Epoch val: g_loss = 0.013298, d_loss = 0.564540, content_loss = 0.012129, advers_loss = 1.169002
# Epoch val disc perf: TP=0.50117, TN=0.94836, FP=0.05164, FN=0.49883
# Epoch took 28.61 seconds
#
# Epoch: 6
# Epoch generator loss = 0.011313, discriminator loss = 0.544750, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.012961, d_loss = 0.536367, content_loss = 0.012169, advers_loss = 0.792430
# Epoch val disc perf: TP=0.92488, TN=0.63967, FP=0.36033, FN=0.07512
# Epoch took 27.97 seconds
#
# Epoch: 7
# Epoch generator loss = 0.011365, discriminator loss = 0.540789, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.013083, d_loss = 0.511449, content_loss = 0.012206, advers_loss = 0.877240
# Epoch val disc perf: TP=0.91901, TN=0.75235, FP=0.24765, FN=0.08099
# Epoch took 28.05 seconds
#
# Epoch: 8
# Epoch generator loss = 0.011446, discriminator loss = 0.515401, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.012799, d_loss = 0.606933, content_loss = 0.012255, advers_loss = 0.544871
# Epoch val disc perf: TP=0.99531, TN=0.25587, FP=0.74413, FN=0.00469
# Epoch took 27.97 seconds
#
# Epoch: 9
# Epoch generator loss = 0.011490, discriminator loss = 0.505098, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.013485, d_loss = 0.486150, content_loss = 0.012261, advers_loss = 1.224080
# Epoch val disc perf: TP=0.69190, TN=0.93721, FP=0.06279, FN=0.30810
# Epoch took 27.95 seconds
#
# Epoch: 10
# Epoch generator loss = 0.011587, discriminator loss = 0.501119, g_count = 40, d_count = 40
# Epoch val: g_loss = 0.013326, d_loss = 0.466616, content_loss = 0.012312, advers_loss = 1.013646
# Epoch val disc perf: TP=0.91080, TN=0.78697, FP=0.21303, FN=0.08920
# Epoch took 28.05 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 11
# Epoch generator loss = 0.011728, discriminator loss = 0.481648, g_count = 43, d_count = 40
# Epoch val: g_loss = 0.013737, d_loss = 0.466732, content_loss = 0.012433, advers_loss = 1.304520
# Epoch val disc perf: TP=0.73592, TN=0.92958, FP=0.07042, FN=0.26408
# Epoch took 29.16 seconds
#
# Epoch: 12
# Epoch generator loss = 0.011769, discriminator loss = 0.477403, g_count = 55, d_count = 40
# Epoch val: g_loss = 0.013741, d_loss = 0.475088, content_loss = 0.012530, advers_loss = 1.210889
# Epoch val disc perf: TP=0.77406, TN=0.88263, FP=0.11737, FN=0.22594
# Epoch took 33.37 seconds
#
# Epoch: 13
# Epoch generator loss = 0.011843, discriminator loss = 0.480755, g_count = 54, d_count = 40
# Epoch val: g_loss = 0.013251, d_loss = 0.547051, content_loss = 0.012564, advers_loss = 0.687453
# Epoch val disc perf: TP=0.98063, TN=0.42488, FP=0.57512, FN=0.01937
# Epoch took 33.13 seconds
#
# Epoch: 14
# Epoch generator loss = 0.011859, discriminator loss = 0.484513, g_count = 55, d_count = 40
# Epoch val: g_loss = 0.013650, d_loss = 0.463978, content_loss = 0.012582, advers_loss = 1.068238
# Epoch val disc perf: TP=0.93486, TN=0.79167, FP=0.20833, FN=0.06514
# Epoch took 33.39 seconds
#
# Epoch: 15
# Epoch generator loss = 0.011947, discriminator loss = 0.468558, g_count = 79, d_count = 40
# Epoch val: g_loss = 0.013602, d_loss = 0.466360, content_loss = 0.012576, advers_loss = 1.026104
# Epoch val disc perf: TP=0.87969, TN=0.76937, FP=0.23063, FN=0.12031
# Epoch took 42.14 seconds
#
# Epoch: 16
# Epoch generator loss = 0.011888, discriminator loss = 0.473665, g_count = 77, d_count = 40
# Epoch val: g_loss = 0.013939, d_loss = 0.455460, content_loss = 0.012675, advers_loss = 1.264072
# Epoch val disc perf: TP=0.80223, TN=0.90962, FP=0.09038, FN=0.19777
# Epoch took 41.45 seconds
#
# Epoch: 17
# Epoch generator loss = 0.012099, discriminator loss = 0.470068, g_count = 51, d_count = 40
# Epoch val: g_loss = 0.013703, d_loss = 0.451187, content_loss = 0.012699, advers_loss = 1.004377
# Epoch val disc perf: TP=0.93662, TN=0.79167, FP=0.20833, FN=0.06338
# Epoch took 31.99 seconds
#
# Epoch: 18
# Epoch generator loss = 0.012102, discriminator loss = 0.472450, g_count = 77, d_count = 40
# Epoch val: g_loss = 0.014333, d_loss = 0.496348, content_loss = 0.012774, advers_loss = 1.559054
# Epoch val disc perf: TP=0.52876, TN=0.96948, FP=0.03052, FN=0.47124
# Epoch took 41.37 seconds
#
# Epoch: 19
# Epoch generator loss = 0.012071, discriminator loss = 0.470019, g_count = 86, d_count = 40
# Epoch val: g_loss = 0.014128, d_loss = 0.471112, content_loss = 0.012680, advers_loss = 1.448039
# Epoch val disc perf: TP=0.63146, TN=0.96596, FP=0.03404, FN=0.36854
# Epoch took 44.75 seconds
#
# Epoch: 20
# Epoch generator loss = 0.012166, discriminator loss = 0.467503, g_count = 68, d_count = 40
# Epoch val: g_loss = 0.013850, d_loss = 0.443378, content_loss = 0.012726, advers_loss = 1.124510
# Epoch val disc perf: TP=0.88322, TN=0.86854, FP=0.13146, FN=0.11678
# Epoch took 38.13 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 21
# Epoch generator loss = 0.012147, discriminator loss = 0.466290, g_count = 51, d_count = 40
# Epoch val: g_loss = 0.013454, d_loss = 0.522931, content_loss = 0.012774, advers_loss = 0.679433
# Epoch val disc perf: TP=0.98474, TN=0.42195, FP=0.57805, FN=0.01526
# Epoch took 31.94 seconds
#
# Epoch: 22
# Epoch generator loss = 0.012172, discriminator loss = 0.476294, g_count = 77, d_count = 40
# Epoch val: g_loss = 0.014315, d_loss = 0.464986, content_loss = 0.012883, advers_loss = 1.431059
# Epoch val disc perf: TP=0.64965, TN=0.97066, FP=0.02934, FN=0.35035
# Epoch took 41.52 seconds
#
# Epoch: 23
# Epoch generator loss = 0.012209, discriminator loss = 0.467187, g_count = 69, d_count = 40
# Epoch val: g_loss = 0.013752, d_loss = 0.501880, content_loss = 0.012968, advers_loss = 0.784241
# Epoch val disc perf: TP=0.97007, TN=0.54871, FP=0.45129, FN=0.02993
# Epoch took 38.57 seconds
#
# Epoch: 24
# Epoch generator loss = 0.012254, discriminator loss = 0.474050, g_count = 54, d_count = 40
# Epoch val: g_loss = 0.014288, d_loss = 0.453083, content_loss = 0.013061, advers_loss = 1.227058
# Epoch val disc perf: TP=0.82512, TN=0.91197, FP=0.08803, FN=0.17488
# Epoch took 33.02 seconds
#
# Epoch: 25
# Epoch generator loss = 0.012288, discriminator loss = 0.467170, g_count = 50, d_count = 40
# Epoch val: g_loss = 0.013706, d_loss = 0.505934, content_loss = 0.012984, advers_loss = 0.722000
# Epoch val disc perf: TP=0.98357, TN=0.47242, FP=0.52758, FN=0.01643
# Epoch took 31.69 seconds
#
# Epoch: 26
# Epoch generator loss = 0.012308, discriminator loss = 0.474734, g_count = 64, d_count = 40
# Epoch val: g_loss = 0.014351, d_loss = 0.488527, content_loss = 0.012991, advers_loss = 1.360631
# Epoch val disc perf: TP=0.63380, TN=0.94425, FP=0.05575, FN=0.36620
# Epoch took 36.70 seconds
#
# Epoch: 27
# Epoch generator loss = 0.012354, discriminator loss = 0.485945, g_count = 55, d_count = 40
# Epoch val: g_loss = 0.014020, d_loss = 0.466192, content_loss = 0.013011, advers_loss = 1.009237
# Epoch val disc perf: TP=0.92136, TN=0.80340, FP=0.19660, FN=0.07864
# Epoch took 33.46 seconds
#
# Epoch: 28
# Epoch generator loss = 0.012232, discriminator loss = 0.467692, g_count = 75, d_count = 40
# Epoch val: g_loss = 0.014218, d_loss = 0.473474, content_loss = 0.012956, advers_loss = 1.262327
# Epoch val disc perf: TP=0.74061, TN=0.92019, FP=0.07981, FN=0.25939
# Epoch took 40.80 seconds
#
# Epoch: 29
# Epoch generator loss = 0.012375, discriminator loss = 0.477320, g_count = 46, d_count = 40
# Epoch val: g_loss = 0.014302, d_loss = 0.466074, content_loss = 0.013127, advers_loss = 1.175060
# Epoch val disc perf: TP=0.81925, TN=0.89437, FP=0.10563, FN=0.18075
# Epoch took 30.15 seconds
#
# Epoch: 30
# Epoch generator loss = 0.012349, discriminator loss = 0.469251, g_count = 53, d_count = 40
# Epoch val: g_loss = 0.014219, d_loss = 0.469685, content_loss = 0.013020, advers_loss = 1.199007
# Epoch val disc perf: TP=0.78521, TN=0.89085, FP=0.10915, FN=0.21479
# Epoch took 32.64 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 31
# Epoch generator loss = 0.012385, discriminator loss = 0.469220, g_count = 60, d_count = 40
# Epoch val: g_loss = 0.014412, d_loss = 0.465804, content_loss = 0.013070, advers_loss = 1.342267
# Epoch val disc perf: TP=0.72124, TN=0.94308, FP=0.05692, FN=0.27876
# Epoch took 35.41 seconds
#
# Epoch: 32
# Epoch generator loss = 0.012417, discriminator loss = 0.467076, g_count = 63, d_count = 40
# Epoch val: g_loss = 0.014313, d_loss = 0.475272, content_loss = 0.013113, advers_loss = 1.199773
# Epoch val disc perf: TP=0.77465, TN=0.89554, FP=0.10446, FN=0.22535
# Epoch took 36.25 seconds
#
# Epoch: 33
# Epoch generator loss = 0.012411, discriminator loss = 0.469598, g_count = 52, d_count = 40
# Epoch val: g_loss = 0.014284, d_loss = 0.468664, content_loss = 0.013234, advers_loss = 1.049646
# Epoch val disc perf: TP=0.87441, TN=0.81925, FP=0.18075, FN=0.12559
# Epoch took 32.29 seconds
#
# Epoch: 34
# Epoch generator loss = 0.012443, discriminator loss = 0.466464, g_count = 61, d_count = 40
# Epoch val: g_loss = 0.014395, d_loss = 0.472511, content_loss = 0.013105, advers_loss = 1.289700
# Epoch val disc perf: TP=0.73533, TN=0.91901, FP=0.08099, FN=0.26467
# Epoch took 35.87 seconds
#
# Epoch: 35
# Epoch generator loss = 0.012524, discriminator loss = 0.464860, g_count = 61, d_count = 40
# Epoch val: g_loss = 0.014703, d_loss = 0.492040, content_loss = 0.013327, advers_loss = 1.376291
# Epoch val disc perf: TP=0.63615, TN=0.94366, FP=0.05634, FN=0.36385
# Epoch took 35.58 seconds
#
# Epoch: 36
# Epoch generator loss = 0.012597, discriminator loss = 0.471473, g_count = 58, d_count = 40
# Epoch val: g_loss = 0.014221, d_loss = 0.489706, content_loss = 0.013292, advers_loss = 0.929823
# Epoch val disc perf: TP=0.92664, TN=0.73181, FP=0.26819, FN=0.07336
# Epoch took 34.56 seconds
#
# Epoch: 37
# Epoch generator loss = 0.012507, discriminator loss = 0.466545, g_count = 76, d_count = 40
# Epoch val: g_loss = 0.014284, d_loss = 0.452943, content_loss = 0.013154, advers_loss = 1.129646
# Epoch val disc perf: TP=0.87617, TN=0.86796, FP=0.13204, FN=0.12383
# Epoch took 41.17 seconds
#
# Epoch: 38
# Epoch generator loss = 0.012488, discriminator loss = 0.477546, g_count = 56, d_count = 40
# Epoch val: g_loss = 0.014217, d_loss = 0.486653, content_loss = 0.013248, advers_loss = 0.969293
# Epoch val disc perf: TP=0.90200, TN=0.77171, FP=0.22829, FN=0.09800
# Epoch took 33.77 seconds
#
# Epoch: 39
# Epoch generator loss = 0.012495, discriminator loss = 0.467850, g_count = 61, d_count = 40
# Epoch val: g_loss = 0.014458, d_loss = 0.491034, content_loss = 0.013301, advers_loss = 1.157492
# Epoch val disc perf: TP=0.77289, TN=0.85153, FP=0.14847, FN=0.22711
# Epoch took 35.62 seconds
#
# Epoch: 40
# Epoch generator loss = 0.012566, discriminator loss = 0.468290, g_count = 56, d_count = 40
# Epoch val: g_loss = 0.014538, d_loss = 0.480002, content_loss = 0.013401, advers_loss = 1.137367
# Epoch val disc perf: TP=0.80340, TN=0.86092, FP=0.13908, FN=0.19660
# Epoch took 33.80 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 41
# Epoch generator loss = 0.012552, discriminator loss = 0.466628, g_count = 52, d_count = 40
# Epoch val: g_loss = 0.014552, d_loss = 0.481501, content_loss = 0.013479, advers_loss = 1.073137
# Epoch val disc perf: TP=0.84155, TN=0.83744, FP=0.16256, FN=0.15845
# Epoch took 32.29 seconds
#
# Epoch: 42
# Epoch generator loss = 0.012575, discriminator loss = 0.463468, g_count = 70, d_count = 40
# Epoch val: g_loss = 0.014402, d_loss = 0.467779, content_loss = 0.013299, advers_loss = 1.103554
# Epoch val disc perf: TP=0.85505, TN=0.85211, FP=0.14789, FN=0.14495
# Epoch took 38.93 seconds
#
# Epoch: 43
# Epoch generator loss = 0.012532, discriminator loss = 0.466615, g_count = 53, d_count = 40
# Epoch val: g_loss = 0.014677, d_loss = 0.488790, content_loss = 0.013337, advers_loss = 1.339971
# Epoch val disc perf: TP=0.64554, TN=0.93721, FP=0.06279, FN=0.35446
# Epoch took 32.57 seconds
#
# Epoch: 44
# Epoch generator loss = 0.012579, discriminator loss = 0.464950, g_count = 57, d_count = 40
# Epoch val: g_loss = 0.014701, d_loss = 0.474007, content_loss = 0.013358, advers_loss = 1.343737
# Epoch val disc perf: TP=0.70423, TN=0.93838, FP=0.06162, FN=0.29577
# Epoch took 34.12 seconds
#
# Epoch: 45
# Epoch generator loss = 0.012603, discriminator loss = 0.469657, g_count = 68, d_count = 40
# Epoch val: g_loss = 0.014514, d_loss = 0.491054, content_loss = 0.013431, advers_loss = 1.083799
# Epoch val disc perf: TP=0.82746, TN=0.81808, FP=0.18192, FN=0.17254
# Epoch took 38.26 seconds
#
# Epoch: 46
# Epoch generator loss = 0.012559, discriminator loss = 0.467917, g_count = 68, d_count = 40
# Epoch val: g_loss = 0.014517, d_loss = 0.484068, content_loss = 0.013388, advers_loss = 1.128846
# Epoch val disc perf: TP=0.79871, TN=0.85094, FP=0.14906, FN=0.20129
# Epoch took 38.24 seconds
#
# Epoch: 47
# Epoch generator loss = 0.012638, discriminator loss = 0.472157, g_count = 47, d_count = 40
# Epoch val: g_loss = 0.014906, d_loss = 0.494123, content_loss = 0.013397, advers_loss = 1.509646
# Epoch val disc perf: TP=0.54577, TN=0.97183, FP=0.02817, FN=0.45423
# Epoch took 30.44 seconds
#
# Epoch: 48
# Epoch generator loss = 0.012635, discriminator loss = 0.470553, g_count = 61, d_count = 40
# Epoch val: g_loss = 0.014394, d_loss = 0.470686, content_loss = 0.013315, advers_loss = 1.078477
# Epoch val disc perf: TP=0.86620, TN=0.82394, FP=0.17606, FN=0.13380
# Epoch took 35.67 seconds
#
# Epoch: 49
# Epoch generator loss = 0.012642, discriminator loss = 0.466825, g_count = 62, d_count = 40
# Epoch val: g_loss = 0.014526, d_loss = 0.489331, content_loss = 0.013477, advers_loss = 1.048753
# Epoch val disc perf: TP=0.83685, TN=0.81045, FP=0.18955, FN=0.16315
# Epoch took 36.04 seconds
#
# Epoch: 50
# Epoch generator loss = 0.012656, discriminator loss = 0.464828, g_count = 52, d_count = 40
# Epoch val: g_loss = 0.014725, d_loss = 0.469089, content_loss = 0.013464, advers_loss = 1.261281
# Epoch val disc perf: TP=0.74296, TN=0.91432, FP=0.08568, FN=0.25704
# Epoch took 32.35 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 51
# Epoch generator loss = 0.012632, discriminator loss = 0.462197, g_count = 65, d_count = 40
# Epoch val: g_loss = 0.014685, d_loss = 0.483555, content_loss = 0.013467, advers_loss = 1.218270
# Epoch val disc perf: TP=0.73298, TN=0.89554, FP=0.10446, FN=0.26702
# Epoch took 37.11 seconds
#
# Epoch: 52
# Epoch generator loss = 0.012710, discriminator loss = 0.464093, g_count = 57, d_count = 40
# Epoch val: g_loss = 0.014621, d_loss = 0.479340, content_loss = 0.013613, advers_loss = 1.008248
# Epoch val disc perf: TP=0.87617, TN=0.76937, FP=0.23063, FN=0.12383
# Epoch took 34.14 seconds
#
# Epoch: 53
# Epoch generator loss = 0.012665, discriminator loss = 0.462630, g_count = 53, d_count = 40
# Epoch val: g_loss = 0.014612, d_loss = 0.468399, content_loss = 0.013427, advers_loss = 1.185726
# Epoch val disc perf: TP=0.79225, TN=0.88498, FP=0.11502, FN=0.20775
# Epoch took 32.62 seconds
#
# Epoch: 54
# Epoch generator loss = 0.012722, discriminator loss = 0.459364, g_count = 60, d_count = 40
# Epoch val: g_loss = 0.014987, d_loss = 0.464517, content_loss = 0.013630, advers_loss = 1.356200
# Epoch val disc perf: TP=0.71538, TN=0.95070, FP=0.04930, FN=0.28462
# Epoch took 35.22 seconds
#
# Epoch: 55
# Epoch generator loss = 0.012753, discriminator loss = 0.463425, g_count = 67, d_count = 40
# Epoch val: g_loss = 0.014762, d_loss = 0.481806, content_loss = 0.013511, advers_loss = 1.250381
# Epoch val disc perf: TP=0.71948, TN=0.91138, FP=0.08862, FN=0.28052
# Epoch took 37.69 seconds
#
# Epoch: 56
# Epoch generator loss = 0.012772, discriminator loss = 0.477692, g_count = 71, d_count = 40
# Epoch val: g_loss = 0.014478, d_loss = 0.454500, content_loss = 0.013376, advers_loss = 1.102358
# Epoch val disc perf: TP=0.89026, TN=0.84038, FP=0.15962, FN=0.10974
# Epoch took 39.29 seconds
#
# Epoch: 57
# Epoch generator loss = 0.012692, discriminator loss = 0.471657, g_count = 80, d_count = 40
# Epoch val: g_loss = 0.014825, d_loss = 0.470713, content_loss = 0.013605, advers_loss = 1.219969
# Epoch val disc perf: TP=0.77523, TN=0.88146, FP=0.11854, FN=0.22477
# Epoch took 42.61 seconds
#
# Epoch: 58
# Epoch generator loss = 0.012810, discriminator loss = 0.478451, g_count = 45, d_count = 40
# Epoch val: g_loss = 0.014772, d_loss = 0.444461, content_loss = 0.013548, advers_loss = 1.224501
# Epoch val disc perf: TP=0.82746, TN=0.90258, FP=0.09742, FN=0.17254
# Epoch took 29.73 seconds
#
# Epoch: 59
# Epoch generator loss = 0.012817, discriminator loss = 0.467665, g_count = 53, d_count = 40
# Epoch val: g_loss = 0.014849, d_loss = 0.463990, content_loss = 0.013611, advers_loss = 1.238327
# Epoch val disc perf: TP=0.77700, TN=0.89965, FP=0.10035, FN=0.22300
# Epoch took 32.77 seconds
#
# Epoch: 60
# Epoch generator loss = 0.012806, discriminator loss = 0.467399, g_count = 62, d_count = 40
# Epoch val: g_loss = 0.014879, d_loss = 0.475123, content_loss = 0.013555, advers_loss = 1.323496
# Epoch val disc perf: TP=0.70246, TN=0.94014, FP=0.05986, FN=0.29754
# Epoch took 36.05 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 61
# Epoch generator loss = 0.012877, discriminator loss = 0.466518, g_count = 60, d_count = 40
# Epoch val: g_loss = 0.014821, d_loss = 0.432168, content_loss = 0.013656, advers_loss = 1.165500
# Epoch val disc perf: TP=0.87911, TN=0.87207, FP=0.12793, FN=0.12089
# Epoch took 35.24 seconds
#
# Epoch: 62
# Epoch generator loss = 0.012840, discriminator loss = 0.470322, g_count = 54, d_count = 40
# Epoch val: g_loss = 0.014770, d_loss = 0.470532, content_loss = 0.013535, advers_loss = 1.235568
# Epoch val disc perf: TP=0.76643, TN=0.90904, FP=0.09096, FN=0.23357
# Epoch took 33.19 seconds
#
# Epoch: 63
# Epoch generator loss = 0.012785, discriminator loss = 0.464707, g_count = 63, d_count = 40
# Epoch val: g_loss = 0.014690, d_loss = 0.478543, content_loss = 0.013555, advers_loss = 1.134245
# Epoch val disc perf: TP=0.81279, TN=0.84624, FP=0.15376, FN=0.18721
# Epoch took 36.36 seconds
#
# Epoch: 64
# Epoch generator loss = 0.012823, discriminator loss = 0.468692, g_count = 64, d_count = 40
# Epoch val: g_loss = 0.014831, d_loss = 0.491736, content_loss = 0.013554, advers_loss = 1.276921
# Epoch val disc perf: TP=0.69601, TN=0.92019, FP=0.07981, FN=0.30399
# Epoch took 36.77 seconds
#
# Epoch: 65
# Epoch generator loss = 0.012853, discriminator loss = 0.468301, g_count = 60, d_count = 40
# Epoch val: g_loss = 0.014771, d_loss = 0.489093, content_loss = 0.013688, advers_loss = 1.082939
# Epoch val disc perf: TP=0.82394, TN=0.81397, FP=0.18603, FN=0.17606
# Epoch took 35.35 seconds
#
# Epoch: 66
# Epoch generator loss = 0.012842, discriminator loss = 0.466815, g_count = 61, d_count = 40
# Epoch val: g_loss = 0.014915, d_loss = 0.468461, content_loss = 0.013657, advers_loss = 1.258566
# Epoch val disc perf: TP=0.76819, TN=0.89965, FP=0.10035, FN=0.23181
# Epoch took 35.59 seconds
#
# Epoch: 67
# Epoch generator loss = 0.012857, discriminator loss = 0.466564, g_count = 54, d_count = 40
# Epoch val: g_loss = 0.014797, d_loss = 0.474212, content_loss = 0.013686, advers_loss = 1.110297
# Epoch val disc perf: TP=0.83157, TN=0.83157, FP=0.16843, FN=0.16843
# Epoch took 33.03 seconds
#
# Epoch: 68
# Epoch generator loss = 0.012905, discriminator loss = 0.460811, g_count = 65, d_count = 40
# Epoch val: g_loss = 0.014908, d_loss = 0.475283, content_loss = 0.013705, advers_loss = 1.202893
# Epoch val disc perf: TP=0.77817, TN=0.88322, FP=0.11678, FN=0.22183
# Epoch took 37.02 seconds
#
# Epoch: 69
# Epoch generator loss = 0.012973, discriminator loss = 0.469133, g_count = 61, d_count = 40
# Epoch val: g_loss = 0.014614, d_loss = 0.455947, content_loss = 0.013625, advers_loss = 0.988869
# Epoch val disc perf: TP=0.93545, TN=0.74707, FP=0.25293, FN=0.06455
# Epoch took 35.57 seconds
#
# Epoch: 70
# Epoch generator loss = 0.012891, discriminator loss = 0.473206, g_count = 78, d_count = 40
# Epoch val: g_loss = 0.015176, d_loss = 0.467660, content_loss = 0.013797, advers_loss = 1.378962
# Epoch val disc perf: TP=0.71009, TN=0.94718, FP=0.05282, FN=0.28991
# Epoch took 41.92 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 71
# Epoch generator loss = 0.012950, discriminator loss = 0.472743, g_count = 56, d_count = 40
# Epoch val: g_loss = 0.014917, d_loss = 0.450190, content_loss = 0.013628, advers_loss = 1.288874
# Epoch val disc perf: TP=0.79460, TN=0.91197, FP=0.08803, FN=0.20540
# Epoch took 33.83 seconds
#
# Epoch: 72
# Epoch generator loss = 0.012947, discriminator loss = 0.468941, g_count = 67, d_count = 40
# Epoch val: g_loss = 0.014828, d_loss = 0.448782, content_loss = 0.013811, advers_loss = 1.016091
# Epoch val disc perf: TP=0.93310, TN=0.77876, FP=0.22124, FN=0.06690
# Epoch took 37.78 seconds
#
# Epoch: 73
# Epoch generator loss = 0.013031, discriminator loss = 0.461778, g_count = 59, d_count = 40
# Epoch val: g_loss = 0.014810, d_loss = 0.439999, content_loss = 0.013639, advers_loss = 1.171443
# Epoch val disc perf: TP=0.88087, TN=0.85857, FP=0.14143, FN=0.11913
# Epoch took 34.97 seconds
#
# Epoch: 74
# Epoch generator loss = 0.012914, discriminator loss = 0.465024, g_count = 64, d_count = 40
# Epoch val: g_loss = 0.014927, d_loss = 0.460391, content_loss = 0.013692, advers_loss = 1.235778
# Epoch val disc perf: TP=0.78580, TN=0.90786, FP=0.09214, FN=0.21420
# Epoch took 36.74 seconds
#
# Epoch: 75
# Epoch generator loss = 0.012921, discriminator loss = 0.465803, g_count = 59, d_count = 40
# Epoch val: g_loss = 0.015014, d_loss = 0.463806, content_loss = 0.013732, advers_loss = 1.281759
# Epoch val disc perf: TP=0.76408, TN=0.92195, FP=0.07805, FN=0.23592
# Epoch took 34.89 seconds
#
# Epoch: 76
# Epoch generator loss = 0.012975, discriminator loss = 0.467236, g_count = 64, d_count = 40
# Epoch val: g_loss = 0.014827, d_loss = 0.466044, content_loss = 0.013828, advers_loss = 0.998934
# Epoch val disc perf: TP=0.91491, TN=0.76291, FP=0.23709, FN=0.08509
# Epoch took 36.68 seconds
#
# Epoch: 77
# Epoch generator loss = 0.012984, discriminator loss = 0.467601, g_count = 69, d_count = 40
# Epoch val: g_loss = 0.014785, d_loss = 0.463031, content_loss = 0.013647, advers_loss = 1.137854
# Epoch val disc perf: TP=0.84800, TN=0.83568, FP=0.16432, FN=0.15200
# Epoch took 38.62 seconds
#
# Epoch: 78
# Epoch generator loss = 0.012966, discriminator loss = 0.467461, g_count = 55, d_count = 40
# Epoch val: g_loss = 0.014740, d_loss = 0.432503, content_loss = 0.013524, advers_loss = 1.215485
# Epoch val disc perf: TP=0.86033, TN=0.88322, FP=0.11678, FN=0.13967
# Epoch took 33.47 seconds
#
# Epoch: 79
# Epoch generator loss = 0.012985, discriminator loss = 0.466575, g_count = 66, d_count = 40
# Epoch val: g_loss = 0.014915, d_loss = 0.452759, content_loss = 0.013630, advers_loss = 1.285335
# Epoch val disc perf: TP=0.78286, TN=0.91549, FP=0.08451, FN=0.21714
# Epoch took 37.54 seconds
#
# Epoch: 80
# Epoch generator loss = 0.013004, discriminator loss = 0.464759, g_count = 69, d_count = 40
# Epoch val: g_loss = 0.015137, d_loss = 0.479194, content_loss = 0.013795, advers_loss = 1.342013
# Epoch val disc perf: TP=0.67899, TN=0.93897, FP=0.06103, FN=0.32101
# Epoch took 38.48 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 81
# Epoch generator loss = 0.012990, discriminator loss = 0.466448, g_count = 64, d_count = 40
# Epoch val: g_loss = 0.015103, d_loss = 0.454491, content_loss = 0.013776, advers_loss = 1.327146
# Epoch val disc perf: TP=0.76056, TN=0.93310, FP=0.06690, FN=0.23944
# Epoch took 36.78 seconds
#
# Epoch: 82
# Epoch generator loss = 0.013027, discriminator loss = 0.465584, g_count = 66, d_count = 40
# Epoch val: g_loss = 0.015006, d_loss = 0.447278, content_loss = 0.013718, advers_loss = 1.288065
# Epoch val disc perf: TP=0.79460, TN=0.92195, FP=0.07805, FN=0.20540
# Epoch took 37.45 seconds
#
# Epoch: 83
# Epoch generator loss = 0.012991, discriminator loss = 0.466345, g_count = 61, d_count = 40
# Epoch val: g_loss = 0.015146, d_loss = 0.452819, content_loss = 0.013962, advers_loss = 1.184402
# Epoch val disc perf: TP=0.83451, TN=0.87852, FP=0.12148, FN=0.16549
# Epoch took 35.62 seconds
#
# Epoch: 84
# Epoch generator loss = 0.013091, discriminator loss = 0.477780, g_count = 73, d_count = 40
# Epoch val: g_loss = 0.014864, d_loss = 0.491761, content_loss = 0.013865, advers_loss = 0.999709
# Epoch val disc perf: TP=0.87031, TN=0.74237, FP=0.25763, FN=0.12969
# Epoch took 40.00 seconds
#
# Epoch: 85
# Epoch generator loss = 0.013027, discriminator loss = 0.469504, g_count = 74, d_count = 40
# Epoch val: g_loss = 0.014906, d_loss = 0.487723, content_loss = 0.013791, advers_loss = 1.115053
# Epoch val disc perf: TP=0.79225, TN=0.82629, FP=0.17371, FN=0.20775
# Epoch took 40.37 seconds
#
# Epoch: 86
# Epoch generator loss = 0.013060, discriminator loss = 0.467687, g_count = 55, d_count = 40
# Epoch val: g_loss = 0.015202, d_loss = 0.485926, content_loss = 0.014001, advers_loss = 1.200821
# Epoch val disc perf: TP=0.73944, TN=0.89319, FP=0.10681, FN=0.26056
# Epoch took 33.38 seconds
#
# Epoch: 87
# Epoch generator loss = 0.013073, discriminator loss = 0.467652, g_count = 78, d_count = 40
# Epoch val: g_loss = 0.015033, d_loss = 0.487941, content_loss = 0.013880, advers_loss = 1.152907
# Epoch val disc perf: TP=0.78873, TN=0.82512, FP=0.17488, FN=0.21127
# Epoch took 41.77 seconds
#
# Epoch: 88
# Epoch generator loss = 0.013105, discriminator loss = 0.471195, g_count = 57, d_count = 40
# Epoch val: g_loss = 0.014979, d_loss = 0.464998, content_loss = 0.013876, advers_loss = 1.103135
# Epoch val disc perf: TP=0.85153, TN=0.82336, FP=0.17664, FN=0.14847
# Epoch took 34.21 seconds
#
# Epoch: 89
# Epoch generator loss = 0.013059, discriminator loss = 0.467028, g_count = 64, d_count = 40
# Epoch val: g_loss = 0.014971, d_loss = 0.443901, content_loss = 0.013716, advers_loss = 1.254431
# Epoch val disc perf: TP=0.82864, TN=0.89143, FP=0.10857, FN=0.17136
# Epoch took 36.79 seconds
#
# Epoch: 90
# Epoch generator loss = 0.013060, discriminator loss = 0.465780, g_count = 58, d_count = 40
# Epoch val: g_loss = 0.014888, d_loss = 0.433013, content_loss = 0.013792, advers_loss = 1.096348
# Epoch val disc perf: TP=0.91843, TN=0.82277, FP=0.17723, FN=0.08157
# Epoch took 34.59 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 91
# Epoch generator loss = 0.013082, discriminator loss = 0.466917, g_count = 78, d_count = 40
# Epoch val: g_loss = 0.015275, d_loss = 0.474127, content_loss = 0.013953, advers_loss = 1.322141
# Epoch val disc perf: TP=0.72300, TN=0.92312, FP=0.07688, FN=0.27700
# Epoch took 41.86 seconds
#
# Epoch: 92
# Epoch generator loss = 0.013139, discriminator loss = 0.470355, g_count = 65, d_count = 40
# Epoch val: g_loss = 0.015356, d_loss = 0.484954, content_loss = 0.013890, advers_loss = 1.466000
# Epoch val disc perf: TP=0.62207, TN=0.95716, FP=0.04284, FN=0.37793
# Epoch took 36.99 seconds
#
# Epoch: 93
# Epoch generator loss = 0.013105, discriminator loss = 0.467333, g_count = 60, d_count = 40
# Epoch val: g_loss = 0.015226, d_loss = 0.471753, content_loss = 0.013912, advers_loss = 1.313325
# Epoch val disc perf: TP=0.73298, TN=0.92254, FP=0.07746, FN=0.26702
# Epoch took 35.25 seconds
#
# Epoch: 94
# Epoch generator loss = 0.013117, discriminator loss = 0.469880, g_count = 76, d_count = 40
# Epoch val: g_loss = 0.014971, d_loss = 0.448958, content_loss = 0.013822, advers_loss = 1.148476
# Epoch val disc perf: TP=0.86385, TN=0.85270, FP=0.14730, FN=0.13615
# Epoch took 41.11 seconds
#
# Epoch: 95
# Epoch generator loss = 0.013109, discriminator loss = 0.471740, g_count = 67, d_count = 40
# Epoch val: g_loss = 0.015512, d_loss = 0.504847, content_loss = 0.013981, advers_loss = 1.531019
# Epoch val disc perf: TP=0.54577, TN=0.96714, FP=0.03286, FN=0.45423
# Epoch took 37.76 seconds
#
# Epoch: 96
# Epoch generator loss = 0.013173, discriminator loss = 0.473818, g_count = 63, d_count = 40
# Epoch val: g_loss = 0.015215, d_loss = 0.491177, content_loss = 0.014048, advers_loss = 1.167041
# Epoch val disc perf: TP=0.77230, TN=0.84214, FP=0.15786, FN=0.22770
# Epoch took 36.31 seconds
#
# Epoch: 97
# Epoch generator loss = 0.013149, discriminator loss = 0.467838, g_count = 68, d_count = 40
# Epoch val: g_loss = 0.014855, d_loss = 0.442493, content_loss = 0.013752, advers_loss = 1.102521
# Epoch val disc perf: TP=0.90023, TN=0.82277, FP=0.17723, FN=0.09977
# Epoch took 38.18 seconds
#
# Epoch: 98
# Epoch generator loss = 0.013121, discriminator loss = 0.465545, g_count = 60, d_count = 40
# Epoch val: g_loss = 0.015211, d_loss = 0.429138, content_loss = 0.013828, advers_loss = 1.383397
# Epoch val disc perf: TP=0.79636, TN=0.94542, FP=0.05458, FN=0.20364
# Epoch took 35.28 seconds
#
# Epoch: 99
# Epoch generator loss = 0.013162, discriminator loss = 0.466246, g_count = 77, d_count = 40
# Epoch val: g_loss = 0.015421, d_loss = 0.466403, content_loss = 0.013893, advers_loss = 1.528229
# Epoch val disc perf: TP=0.64143, TN=0.96479, FP=0.03521, FN=0.35857
# Epoch took 41.41 seconds
#
# Epoch: 100
# Epoch generator loss = 0.013175, discriminator loss = 0.466602, g_count = 62, d_count = 40
# Epoch val: g_loss = 0.015172, d_loss = 0.477748, content_loss = 0.013973, advers_loss = 1.198851
# Epoch val disc perf: TP=0.79930, TN=0.83392, FP=0.16608, FN=0.20070
# Epoch took 36.09 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done.

# %%
from time import time

@tf.function
def train_step(generator, discriminator, generator_optimizer, discriminator_optimizer, batch_LR, batch_HR, alpha_advers=0.001):
    
    g_count = 0
    d_loss = tf.constant(0.0)
    d_HR = discriminator(batch_HR, training=False)
    while(d_loss < tf.constant(0.5) and g_count < 40):
        g_count += 1
        with tf.GradientTape() as gen_tape:
            batch_SR = generator(batch_LR, training=True)
            d_SR = discriminator(batch_SR, training=False)
            g_loss, content_loss, g_advers_loss = generator_loss(batch_HR, batch_SR, d_SR, alpha_advers=alpha_advers)

        grad_of_gen = gen_tape.gradient(g_loss, generator.trainable_variables)
        generator_optimizer.apply_gradients(zip(grad_of_gen, generator.trainable_variables))
        d_loss, _ = discriminator_loss(d_HR, d_SR)

    d_count = 0
    d_loss = tf.constant(100.0)
    while(d_loss > tf.constant(0.7) and d_count < 40):
        d_count += 1
        with tf.GradientTape() as disc_tape:
            batch_SR = generator(batch_LR, training=False)
            d_HR = discriminator(batch_HR, training=True)
            d_SR = discriminator(batch_SR, training=True)
            d_loss, _ = discriminator_loss(d_HR, d_SR)

        grad_of_disc = disc_tape.gradient(d_loss, discriminator.trainable_variables)
        discriminator_optimizer.apply_gradients(zip(grad_of_disc, discriminator.trainable_variables))
       
    return g_loss, d_loss, g_count, d_count

def train(gen_model, disc_model, epochs=20, batch_size=128, alpha_advers=0.001):
    '''
        This method trains the generator and disctiminator adversarially
        Notice the two model should be argument of this function
        output: generator model and discriminator model
    '''

    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size)
    batch_count = tf.data.experimental.cardinality(train_dataset)
    
    g_opt = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    d_opt = tf.keras.optimizers.Adam(learning_rate=4e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

    # Start training
    print('Training network ...')
    for epoch in range(1, epochs+1):
        print('Epoch: %d' %(epoch))
        start_time = time()
        epoch_g_loss, epoch_d_loss, N, g_count_tot, d_count_tot = 0, 0, 0, 0, 0
        
        for batch_idx, (batch_LR, batch_HR) in enumerate(train_dataset):
            N_batch = batch_LR.shape[0]
            g_loss, d_loss, g_count, d_count = train_step(gen_model, disc_model, g_opt, d_opt, batch_LR, batch_HR, alpha_advers)
            
            epoch_g_loss += g_loss * N_batch
            epoch_d_loss += d_loss * N_batch
            N += N_batch
            g_count_tot += g_count
            d_count_tot += d_count

        epoch_g_loss = epoch_g_loss / N       
        epoch_d_loss = epoch_d_loss / N       
        
        val_SR = gen_model.predict(x_val, verbose=0)
        val_d_HR = disc_model.predict(y_val, verbose=0)
        val_d_SR = disc_model.predict(val_SR, verbose=0)
        
        val_g_loss, val_content_loss, val_advers_loss = generator_loss(y_val, val_SR, val_d_SR, alpha_advers)
        val_d_loss, val_disc_perf = discriminator_loss(val_d_HR, val_d_SR)
        
        print('Epoch generator loss = %.6f, discriminator loss = %.6f, g_count = %d, d_count = %d' %(epoch_g_loss, epoch_d_loss, g_count_tot, d_count_tot))
        print('Epoch val: g_loss = %.6f, d_loss = %.6f, content_loss = %.6f, advers_loss = %.6f' \
              %(val_g_loss, val_d_loss, val_content_loss, val_advers_loss))
        print('Epoch val disc perf: TP=%.5f, TN=%.5f, FP=%.5f, FN=%.5f' %(val_disc_perf[0], val_disc_perf[1], val_disc_perf[2], val_disc_perf[3]))
        print('Epoch took %.2f seconds\n' %(time() - start_time), flush=True)
        
        if (epoch % 2 == 0):
            gen_model.save('gan_train/gen-model-epoch-%d.h5' %(epoch+280))
            disc_model.save('gan_train/disc-model-epoch-%d.h5' %(epoch+280))

    print('Done.')

    return gen_model, disc_model

# %%
gen_model = tf.keras.models.load_model('gan_train/gen-model-epoch-280.h5')
disc_model = tf.keras.models.load_model('gan_train/disc-model-epoch-280.h5')

val_SR = gen_model.predict(x_val, verbose=0)
val_d_HR = disc_model.predict(y_val, verbose=0)
val_d_SR = disc_model.predict(val_SR, verbose=0)

val_g_loss, val_content_loss, val_advers_loss = generator_loss(y_val, val_SR, val_d_SR, 0.001)
val_d_loss, val_disc_perf = discriminator_loss(val_d_HR, val_d_SR)

print('Epoch val: g_loss = %.6f, d_loss = %.6f, content_loss = %.6f, advers_loss = %.6f' \
      %(val_g_loss, val_d_loss, val_content_loss, val_advers_loss))
print('Epoch val disc perf: TP=%.5f, TN=%.5f, FP=%.5f, FN=%.5f' %(val_disc_perf[0], val_disc_perf[1], val_disc_perf[2], val_disc_perf[3]))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-07-17 08:45:54.882581: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch val: g_loss = 0.015782, d_loss = 0.500255, content_loss = 0.014153, advers_loss = 1.628517
# Epoch val disc perf: TP=0.63380, TN=0.84624, FP=0.15376, FN=0.36620

# %%
gen_model_final, disc_model_final = train(gen_model, disc_model, epochs=40, batch_size=128, alpha_advers=0.001)
# Out:
# Training network ...
# Epoch: 1
# Epoch generator loss = 0.012713, discriminator loss = 0.498882, g_count = 386, d_count = 41
# Epoch val: g_loss = 0.015188, d_loss = 0.468793, content_loss = 0.013782, advers_loss = 1.405567
# Epoch val disc perf: TP=0.76995, TN=0.76819, FP=0.23181, FN=0.23005
# Epoch took 149.65 seconds
#
# Epoch: 2
# Epoch generator loss = 0.011924, discriminator loss = 0.512821, g_count = 196, d_count = 40
# Epoch val: g_loss = 0.015203, d_loss = 0.473740, content_loss = 0.013901, advers_loss = 1.302227
# Epoch val disc perf: TP=0.80810, TN=0.73298, FP=0.26702, FN=0.19190
# Epoch took 76.02 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 3
# Epoch generator loss = 0.011821, discriminator loss = 0.513881, g_count = 180, d_count = 40
# Epoch val: g_loss = 0.015326, d_loss = 0.501632, content_loss = 0.014083, advers_loss = 1.242618
# Epoch val disc perf: TP=0.80751, TN=0.67019, FP=0.32981, FN=0.19249
# Epoch took 70.80 seconds
#
# Epoch: 4
# Epoch generator loss = 0.011855, discriminator loss = 0.516255, g_count = 149, d_count = 40
# Epoch val: g_loss = 0.016013, d_loss = 0.629854, content_loss = 0.014322, advers_loss = 1.691414
# Epoch val disc perf: TP=0.40082, TN=0.83803, FP=0.16197, FN=0.59918
# Epoch took 60.70 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 5
# Epoch generator loss = 0.011850, discriminator loss = 0.514639, g_count = 165, d_count = 40
# Epoch val: g_loss = 0.015548, d_loss = 0.548920, content_loss = 0.013959, advers_loss = 1.588550
# Epoch val disc perf: TP=0.67254, TN=0.76174, FP=0.23826, FN=0.32746
# Epoch took 65.87 seconds
#
# Epoch: 6
# Epoch generator loss = 0.011792, discriminator loss = 0.514059, g_count = 175, d_count = 40
# Epoch val: g_loss = 0.015780, d_loss = 0.544658, content_loss = 0.014017, advers_loss = 1.762814
# Epoch val disc perf: TP=0.50059, TN=0.89789, FP=0.10211, FN=0.49941
# Epoch took 69.26 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 7
# Epoch generator loss = 0.011793, discriminator loss = 0.512174, g_count = 191, d_count = 40
# Epoch val: g_loss = 0.015947, d_loss = 0.526677, content_loss = 0.014140, advers_loss = 1.807082
# Epoch val disc perf: TP=0.50235, TN=0.94836, FP=0.05164, FN=0.49765
# Epoch took 74.35 seconds
#
# Epoch: 8
# Epoch generator loss = 0.011828, discriminator loss = 0.510688, g_count = 167, d_count = 40
# Epoch val: g_loss = 0.015876, d_loss = 0.523444, content_loss = 0.014006, advers_loss = 1.869282
# Epoch val disc perf: TP=0.50704, TN=0.94660, FP=0.05340, FN=0.49296
# Epoch took 66.38 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 9
# Epoch generator loss = 0.011849, discriminator loss = 0.508879, g_count = 171, d_count = 40
# Epoch val: g_loss = 0.016046, d_loss = 0.552165, content_loss = 0.014028, advers_loss = 2.018058
# Epoch val disc perf: TP=0.43662, TN=0.97418, FP=0.02582, FN=0.56338
# Epoch took 67.76 seconds
#
# Epoch: 10
# Epoch generator loss = 0.011877, discriminator loss = 0.510445, g_count = 147, d_count = 40
# Epoch val: g_loss = 0.015617, d_loss = 0.493568, content_loss = 0.014011, advers_loss = 1.605129
# Epoch val disc perf: TP=0.65786, TN=0.85387, FP=0.14613, FN=0.34214
# Epoch took 59.99 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 11
# Epoch generator loss = 0.011864, discriminator loss = 0.510713, g_count = 147, d_count = 40
# Epoch val: g_loss = 0.016042, d_loss = 0.518298, content_loss = 0.014108, advers_loss = 1.933541
# Epoch val disc perf: TP=0.50646, TN=0.92840, FP=0.07160, FN=0.49354
# Epoch took 59.88 seconds
#
# Epoch: 12
# Epoch generator loss = 0.011891, discriminator loss = 0.506502, g_count = 151, d_count = 40
# Epoch val: g_loss = 0.015956, d_loss = 0.552312, content_loss = 0.013977, advers_loss = 1.979403
# Epoch val disc perf: TP=0.44425, TN=0.95951, FP=0.04049, FN=0.55575
# Epoch took 61.29 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 13
# Epoch generator loss = 0.011831, discriminator loss = 0.511353, g_count = 168, d_count = 40
# Epoch val: g_loss = 0.015735, d_loss = 0.491160, content_loss = 0.014042, advers_loss = 1.692729
# Epoch val disc perf: TP=0.62383, TN=0.89847, FP=0.10153, FN=0.37617
# Epoch took 66.75 seconds
#
# Epoch: 14
# Epoch generator loss = 0.011903, discriminator loss = 0.515902, g_count = 158, d_count = 40
# Epoch val: g_loss = 0.015880, d_loss = 0.534751, content_loss = 0.014269, advers_loss = 1.611151
# Epoch val disc perf: TP=0.56279, TN=0.86796, FP=0.13204, FN=0.43721
# Epoch took 63.70 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 15
# Epoch generator loss = 0.011968, discriminator loss = 0.513182, g_count = 119, d_count = 40
# Epoch val: g_loss = 0.015176, d_loss = 0.417877, content_loss = 0.013716, advers_loss = 1.460221
# Epoch val disc perf: TP=0.82629, TN=0.80223, FP=0.19777, FN=0.17371
# Epoch took 50.98 seconds
#
# Epoch: 16
# Epoch generator loss = 0.011927, discriminator loss = 0.515798, g_count = 128, d_count = 40
# Epoch val: g_loss = 0.015911, d_loss = 0.494479, content_loss = 0.014184, advers_loss = 1.726451
# Epoch val disc perf: TP=0.63967, TN=0.85270, FP=0.14730, FN=0.36033
# Epoch took 53.78 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 17
# Epoch generator loss = 0.011870, discriminator loss = 0.511023, g_count = 177, d_count = 40
# Epoch val: g_loss = 0.015249, d_loss = 0.501597, content_loss = 0.013941, advers_loss = 1.308427
# Epoch val disc perf: TP=0.87617, TN=0.66197, FP=0.33803, FN=0.12383
# Epoch took 69.67 seconds
#
# Epoch: 18
# Epoch generator loss = 0.011827, discriminator loss = 0.507125, g_count = 167, d_count = 40
# Epoch val: g_loss = 0.015622, d_loss = 0.474612, content_loss = 0.013955, advers_loss = 1.667072
# Epoch val disc perf: TP=0.71362, TN=0.80282, FP=0.19718, FN=0.28638
# Epoch took 66.51 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 19
# Epoch generator loss = 0.011868, discriminator loss = 0.512222, g_count = 168, d_count = 40
# Epoch val: g_loss = 0.015444, d_loss = 0.493534, content_loss = 0.014109, advers_loss = 1.335275
# Epoch val disc perf: TP=0.83275, TN=0.65728, FP=0.34272, FN=0.16725
# Epoch took 66.80 seconds
#
# Epoch: 20
# Epoch generator loss = 0.011864, discriminator loss = 0.509632, g_count = 168, d_count = 40
# Epoch val: g_loss = 0.015686, d_loss = 0.461747, content_loss = 0.013953, advers_loss = 1.733242
# Epoch val disc perf: TP=0.69249, TN=0.89143, FP=0.10857, FN=0.30751
# Epoch took 66.86 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 21
# Epoch generator loss = 0.011826, discriminator loss = 0.503066, g_count = 167, d_count = 40
# Epoch val: g_loss = 0.015964, d_loss = 0.528786, content_loss = 0.014200, advers_loss = 1.764430
# Epoch val disc perf: TP=0.56455, TN=0.86385, FP=0.13615, FN=0.43545
# Epoch took 66.54 seconds
#
# Epoch: 22
# Epoch generator loss = 0.011984, discriminator loss = 0.513105, g_count = 132, d_count = 40
# Epoch val: g_loss = 0.015503, d_loss = 0.476882, content_loss = 0.014112, advers_loss = 1.391172
# Epoch val disc perf: TP=0.78462, TN=0.74296, FP=0.25704, FN=0.21538
# Epoch took 55.15 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 23
# Epoch generator loss = 0.011807, discriminator loss = 0.506499, g_count = 176, d_count = 40
# Epoch val: g_loss = 0.016271, d_loss = 0.543644, content_loss = 0.013993, advers_loss = 2.277928
# Epoch val disc perf: TP=0.43016, TN=0.96890, FP=0.03110, FN=0.56984
# Epoch took 69.40 seconds
#
# Epoch: 24
# Epoch generator loss = 0.011930, discriminator loss = 0.519724, g_count = 136, d_count = 40
# Epoch val: g_loss = 0.016543, d_loss = 0.664541, content_loss = 0.014129, advers_loss = 2.414165
# Epoch val disc perf: TP=0.24589, TN=0.98768, FP=0.01232, FN=0.75411
# Epoch took 56.37 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 25
# Epoch generator loss = 0.011834, discriminator loss = 0.508290, g_count = 164, d_count = 40
# Epoch val: g_loss = 0.016124, d_loss = 0.546520, content_loss = 0.013919, advers_loss = 2.204647
# Epoch val disc perf: TP=0.44601, TN=0.96655, FP=0.03345, FN=0.55399
# Epoch took 65.40 seconds
#
# Epoch: 26
# Epoch generator loss = 0.011751, discriminator loss = 0.509517, g_count = 207, d_count = 40
# Epoch val: g_loss = 0.016187, d_loss = 0.539740, content_loss = 0.014114, advers_loss = 2.073365
# Epoch val disc perf: TP=0.46831, TN=0.94190, FP=0.05810, FN=0.53169
# Epoch took 79.38 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 27
# Epoch generator loss = 0.011763, discriminator loss = 0.507671, g_count = 196, d_count = 40
# Epoch val: g_loss = 0.016609, d_loss = 0.565119, content_loss = 0.014271, advers_loss = 2.338348
# Epoch val disc perf: TP=0.38322, TN=0.98650, FP=0.01350, FN=0.61678
# Epoch took 75.86 seconds
#
# Epoch: 28
# Epoch generator loss = 0.011839, discriminator loss = 0.508034, g_count = 166, d_count = 40
# Epoch val: g_loss = 0.015936, d_loss = 0.471234, content_loss = 0.013869, advers_loss = 2.067085
# Epoch val disc perf: TP=0.61150, TN=0.90669, FP=0.09331, FN=0.38850
# Epoch took 66.09 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 29
# Epoch generator loss = 0.011894, discriminator loss = 0.511420, g_count = 137, d_count = 40
# Epoch val: g_loss = 0.015794, d_loss = 0.485966, content_loss = 0.013995, advers_loss = 1.798660
# Epoch val disc perf: TP=0.57218, TN=0.94601, FP=0.05399, FN=0.42782
# Epoch took 56.74 seconds
#
# Epoch: 30
# Epoch generator loss = 0.011803, discriminator loss = 0.502832, g_count = 187, d_count = 40
# Epoch val: g_loss = 0.016031, d_loss = 0.508864, content_loss = 0.014073, advers_loss = 1.958126
# Epoch val disc perf: TP=0.51995, TN=0.95188, FP=0.04812, FN=0.48005
# Epoch took 72.84 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 31
# Epoch generator loss = 0.011900, discriminator loss = 0.514523, g_count = 150, d_count = 40
# Epoch val: g_loss = 0.015703, d_loss = 0.437170, content_loss = 0.014061, advers_loss = 1.641901
# Epoch val disc perf: TP=0.79988, TN=0.78815, FP=0.21185, FN=0.20012
# Epoch took 60.96 seconds
#
# Epoch: 32
# Epoch generator loss = 0.011864, discriminator loss = 0.513857, g_count = 137, d_count = 40
# Epoch val: g_loss = 0.015881, d_loss = 0.503691, content_loss = 0.014041, advers_loss = 1.839632
# Epoch val disc perf: TP=0.62969, TN=0.83568, FP=0.16432, FN=0.37031
# Epoch took 56.65 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 33
# Epoch generator loss = 0.011842, discriminator loss = 0.506855, g_count = 152, d_count = 40
# Epoch val: g_loss = 0.015259, d_loss = 0.410256, content_loss = 0.013788, advers_loss = 1.470978
# Epoch val disc perf: TP=0.87852, TN=0.76995, FP=0.23005, FN=0.12148
# Epoch took 61.64 seconds
#
# Epoch: 34
# Epoch generator loss = 0.011850, discriminator loss = 0.511774, g_count = 152, d_count = 40
# Epoch val: g_loss = 0.015588, d_loss = 0.430904, content_loss = 0.013995, advers_loss = 1.592767
# Epoch val disc perf: TP=0.78580, TN=0.83333, FP=0.16667, FN=0.21420
# Epoch took 61.67 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 35
# Epoch generator loss = 0.011845, discriminator loss = 0.513794, g_count = 135, d_count = 40
# Epoch val: g_loss = 0.016007, d_loss = 0.508445, content_loss = 0.014265, advers_loss = 1.741523
# Epoch val disc perf: TP=0.58451, TN=0.91021, FP=0.08979, FN=0.41549
# Epoch took 56.07 seconds
#
# Epoch: 36
# Epoch generator loss = 0.011814, discriminator loss = 0.516195, g_count = 146, d_count = 40
# Epoch val: g_loss = 0.015601, d_loss = 0.468524, content_loss = 0.014159, advers_loss = 1.442741
# Epoch val disc perf: TP=0.80516, TN=0.74824, FP=0.25176, FN=0.19484
# Epoch took 59.70 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 37
# Epoch generator loss = 0.011761, discriminator loss = 0.507897, g_count = 161, d_count = 40
# Epoch val: g_loss = 0.016116, d_loss = 0.515914, content_loss = 0.014284, advers_loss = 1.832044
# Epoch val disc perf: TP=0.54871, TN=0.91256, FP=0.08744, FN=0.45129
# Epoch took 64.50 seconds
#
# Epoch: 38
# Epoch generator loss = 0.011709, discriminator loss = 0.506560, g_count = 211, d_count = 40
# Epoch val: g_loss = 0.016099, d_loss = 0.524034, content_loss = 0.014147, advers_loss = 1.952734
# Epoch val disc perf: TP=0.54225, TN=0.91491, FP=0.08509, FN=0.45775
# Epoch took 80.78 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 39
# Epoch generator loss = 0.011803, discriminator loss = 0.512316, g_count = 172, d_count = 40
# Epoch val: g_loss = 0.015559, d_loss = 0.464862, content_loss = 0.014122, advers_loss = 1.437298
# Epoch val disc perf: TP=0.85622, TN=0.69425, FP=0.30575, FN=0.14378
# Epoch took 68.01 seconds
#
# Epoch: 40
# Epoch generator loss = 0.011764, discriminator loss = 0.513444, g_count = 195, d_count = 40
# Epoch val: g_loss = 0.015770, d_loss = 0.484087, content_loss = 0.014193, advers_loss = 1.576711
# Epoch val disc perf: TP=0.67488, TN=0.85563, FP=0.14437, FN=0.32512
# Epoch took 75.68 seconds
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done.

# %%
for i in range(180, 220, 2):
    
    gen_model = tf.keras.models.load_model('gan_train/gen-model-epoch-{}.h5'.format(i+100))
    disc_model = tf.keras.models.load_model('gan_train/disc-model-epoch-{}.h5'.format(i))

    val_SR = gen_model.predict(x_val, verbose=0)
    val_d_HR = disc_model.predict(y_val, verbose=0)
    val_d_SR = disc_model.predict(val_SR, verbose=0)

    val_g_loss, val_content_loss, val_advers_loss = generator_loss(y_val, val_SR, val_d_SR, 0.001)
    val_d_loss, val_disc_perf = discriminator_loss(val_d_HR, val_d_SR)

    print('Model {}:'.format(i))
    print('Epoch val: g_loss = %.6f, d_loss = %.6f, content_loss = %.6f, advers_loss = %.6f' \
          %(val_g_loss, val_d_loss, val_content_loss, val_advers_loss))
    print('Epoch val disc perf: TP=%.5f, TN=%.5f, FP=%.5f, FN=%.5f' %(val_disc_perf[0], val_disc_perf[1], val_disc_perf[2], val_disc_perf[3]))
    
    test_SR = gen_model.predict(x_test, verbose=0)
    test_d_HR = disc_model.predict(y_test, verbose=0)
    test_d_SR = disc_model.predict(test_SR, verbose=0)

    test_g_loss, test_content_loss, test_advers_loss = generator_loss(y_test, test_SR, test_d_SR, 0.001)
    test_d_loss, test_disc_perf = discriminator_loss(test_d_HR, test_d_SR)

    print('Epoch test: g_loss = %.6f, d_loss = %.6f, content_loss = %.6f, advers_loss = %.6f' \
          %(test_g_loss, test_d_loss, test_content_loss, test_advers_loss))
    print('Epoch test disc perf: TP=%.5f, TN=%.5f, FP=%.5f, FN=%.5f' %(test_disc_perf[0], test_disc_perf[1], test_disc_perf[2], test_disc_perf[3]))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 180:
# Epoch val: g_loss = 0.014371, d_loss = 1.374425, content_loss = 0.014153, advers_loss = 0.217657
# Epoch val disc perf: TP=0.87383, TN=0.06631, FP=0.93369, FN=0.12617
# Epoch test: g_loss = 0.014097, d_loss = 1.417458, content_loss = 0.013898, advers_loss = 0.198370
# Epoch test disc perf: TP=0.86913, TN=0.05692, FP=0.94308, FN=0.13087
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 182:
# Epoch val: g_loss = 0.015203, d_loss = 0.473735, content_loss = 0.013901, advers_loss = 1.302238
# Epoch val disc perf: TP=0.80810, TN=0.73239, FP=0.26761, FN=0.19190
# Epoch test: g_loss = 0.014888, d_loss = 0.485003, content_loss = 0.013641, advers_loss = 1.247303
# Epoch test disc perf: TP=0.80810, TN=0.72653, FP=0.27347, FN=0.19190
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 184:
# Epoch val: g_loss = 0.016013, d_loss = 0.629861, content_loss = 0.014322, advers_loss = 1.691400
# Epoch val disc perf: TP=0.40082, TN=0.83862, FP=0.16138, FN=0.59918
# Epoch test: g_loss = 0.015711, d_loss = 0.639831, content_loss = 0.014058, advers_loss = 1.652977
# Epoch test disc perf: TP=0.38908, TN=0.83979, FP=0.16021, FN=0.61092
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 186:
# Epoch val: g_loss = 0.015780, d_loss = 0.544652, content_loss = 0.014017, advers_loss = 1.762828
# Epoch val disc perf: TP=0.50059, TN=0.89789, FP=0.10211, FN=0.49941
# Epoch test: g_loss = 0.015445, d_loss = 0.554146, content_loss = 0.013759, advers_loss = 1.686182
# Epoch test disc perf: TP=0.48357, TN=0.88146, FP=0.11854, FN=0.51643
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 188:
# Epoch val: g_loss = 0.015876, d_loss = 0.523443, content_loss = 0.014006, advers_loss = 1.869278
# Epoch val disc perf: TP=0.50704, TN=0.94660, FP=0.05340, FN=0.49296
# Epoch test: g_loss = 0.015542, d_loss = 0.531139, content_loss = 0.013729, advers_loss = 1.812644
# Epoch test disc perf: TP=0.49178, TN=0.94894, FP=0.05106, FN=0.50822
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 190:
# Epoch val: g_loss = 0.015617, d_loss = 0.493560, content_loss = 0.014011, advers_loss = 1.605123
# Epoch val disc perf: TP=0.65786, TN=0.85387, FP=0.14613, FN=0.34214
# Epoch test: g_loss = 0.015312, d_loss = 0.504074, content_loss = 0.013755, advers_loss = 1.557168
# Epoch test disc perf: TP=0.65376, TN=0.84918, FP=0.15082, FN=0.34624
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 192:
# Epoch val: g_loss = 0.015956, d_loss = 0.552310, content_loss = 0.013977, advers_loss = 1.979384
# Epoch val disc perf: TP=0.44425, TN=0.95951, FP=0.04049, FN=0.55575
# Epoch test: g_loss = 0.015624, d_loss = 0.563356, content_loss = 0.013701, advers_loss = 1.923249
# Epoch test disc perf: TP=0.41373, TN=0.95012, FP=0.04988, FN=0.58627
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 194:
# Epoch val: g_loss = 0.015880, d_loss = 0.534755, content_loss = 0.014269, advers_loss = 1.611137
# Epoch val disc perf: TP=0.56279, TN=0.86854, FP=0.13146, FN=0.43721
# Epoch test: g_loss = 0.015548, d_loss = 0.548525, content_loss = 0.014013, advers_loss = 1.535465
# Epoch test disc perf: TP=0.55106, TN=0.85035, FP=0.14965, FN=0.44894
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 196:
# Epoch val: g_loss = 0.015911, d_loss = 0.494472, content_loss = 0.014184, advers_loss = 1.726482
# Epoch val disc perf: TP=0.63967, TN=0.85270, FP=0.14730, FN=0.36033
# Epoch test: g_loss = 0.015591, d_loss = 0.506693, content_loss = 0.013933, advers_loss = 1.657822
# Epoch test disc perf: TP=0.63028, TN=0.84155, FP=0.15845, FN=0.36972
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 198:
# Epoch val: g_loss = 0.015622, d_loss = 0.474607, content_loss = 0.013955, advers_loss = 1.667045
# Epoch val disc perf: TP=0.71362, TN=0.80282, FP=0.19718, FN=0.28638
# Epoch test: g_loss = 0.015278, d_loss = 0.485058, content_loss = 0.013688, advers_loss = 1.590146
# Epoch test disc perf: TP=0.70657, TN=0.79401, FP=0.20599, FN=0.29343
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 200:
# Epoch val: g_loss = 0.015686, d_loss = 0.461758, content_loss = 0.013953, advers_loss = 1.733217
# Epoch val disc perf: TP=0.69249, TN=0.89085, FP=0.10915, FN=0.30751
# Epoch test: g_loss = 0.015339, d_loss = 0.471269, content_loss = 0.013683, advers_loss = 1.656911
# Epoch test disc perf: TP=0.67899, TN=0.88556, FP=0.11444, FN=0.32101
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 202:
# Epoch val: g_loss = 0.015503, d_loss = 0.476888, content_loss = 0.014112, advers_loss = 1.391138
# Epoch val disc perf: TP=0.78462, TN=0.74354, FP=0.25646, FN=0.21538
# Epoch test: g_loss = 0.015206, d_loss = 0.488791, content_loss = 0.013857, advers_loss = 1.349056
# Epoch test disc perf: TP=0.77523, TN=0.73239, FP=0.26761, FN=0.22477
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 204:
# Epoch val: g_loss = 0.016543, d_loss = 0.664544, content_loss = 0.014129, advers_loss = 2.414162
# Epoch val disc perf: TP=0.24589, TN=0.98768, FP=0.01232, FN=0.75411
# Epoch test: g_loss = 0.016225, d_loss = 0.674200, content_loss = 0.013872, advers_loss = 2.353418
# Epoch test disc perf: TP=0.24002, TN=0.98650, FP=0.01350, FN=0.75998
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 206:
# Epoch val: g_loss = 0.016187, d_loss = 0.539730, content_loss = 0.014114, advers_loss = 2.073419
# Epoch val disc perf: TP=0.46831, TN=0.94190, FP=0.05810, FN=0.53169
# Epoch test: g_loss = 0.015866, d_loss = 0.544470, content_loss = 0.013858, advers_loss = 2.007230
# Epoch test disc perf: TP=0.46127, TN=0.92958, FP=0.07042, FN=0.53873
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 208:
# Epoch val: g_loss = 0.015936, d_loss = 0.471234, content_loss = 0.013869, advers_loss = 2.067039
# Epoch val disc perf: TP=0.61150, TN=0.90669, FP=0.09331, FN=0.38850
# Epoch test: g_loss = 0.015591, d_loss = 0.476328, content_loss = 0.013594, advers_loss = 1.997513
# Epoch test disc perf: TP=0.62265, TN=0.90023, FP=0.09977, FN=0.37735
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 210:
# Epoch val: g_loss = 0.016031, d_loss = 0.508855, content_loss = 0.014073, advers_loss = 1.958159
# Epoch val disc perf: TP=0.51995, TN=0.95188, FP=0.04812, FN=0.48005
# Epoch test: g_loss = 0.015697, d_loss = 0.514828, content_loss = 0.013806, advers_loss = 1.890285
# Epoch test disc perf: TP=0.51467, TN=0.94836, FP=0.05164, FN=0.48533
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 212:
# Epoch val: g_loss = 0.015881, d_loss = 0.503681, content_loss = 0.014041, advers_loss = 1.839681
# Epoch val disc perf: TP=0.62969, TN=0.83568, FP=0.16432, FN=0.37031
# Epoch test: g_loss = 0.015536, d_loss = 0.509733, content_loss = 0.013773, advers_loss = 1.762105
# Epoch test disc perf: TP=0.62383, TN=0.82746, FP=0.17254, FN=0.37617
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 214:
# Epoch val: g_loss = 0.015588, d_loss = 0.430911, content_loss = 0.013995, advers_loss = 1.592746
# Epoch val disc perf: TP=0.78580, TN=0.83333, FP=0.16667, FN=0.21420
# Epoch test: g_loss = 0.015246, d_loss = 0.436813, content_loss = 0.013724, advers_loss = 1.521985
# Epoch test disc perf: TP=0.77700, TN=0.83685, FP=0.16315, FN=0.22300
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 216:
# Epoch val: g_loss = 0.015601, d_loss = 0.468529, content_loss = 0.014159, advers_loss = 1.442726
# Epoch val disc perf: TP=0.80516, TN=0.74765, FP=0.25235, FN=0.19484
# Epoch test: g_loss = 0.015227, d_loss = 0.473152, content_loss = 0.013881, advers_loss = 1.346512
# Epoch test disc perf: TP=0.81338, TN=0.74589, FP=0.25411, FN=0.18662
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model 218:
# Epoch val: g_loss = 0.016099, d_loss = 0.524033, content_loss = 0.014147, advers_loss = 1.952722
# Epoch val disc perf: TP=0.54225, TN=0.91491, FP=0.08509, FN=0.45775
# Epoch test: g_loss = 0.015732, d_loss = 0.529689, content_loss = 0.013864, advers_loss = 1.868112
# Epoch test disc perf: TP=0.52876, TN=0.91256, FP=0.08744, FN=0.47124
